# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# The simplest plot ever
# create the time series
t = np.arange(0.0, 2.0, 0.01)
# create the respective sine function
s = 1 + np.sin(2 * np.pi*t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
# multiple subplots example
x1 = np.linspace(0.0, 5.0, num = 30)
x2 = np.linspace(0.0, 2.0, num = 30)
# x1.size == 1000 && x2.size == 1000

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x1)

# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot check this out
# https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot
plt.subplot(211)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %%
"""
Matplotlib hierarchy
"""
# figure
fig = plt.figure() # creates an empty figure
fig.suptitle('No axes on this figure.') # adds a title to the figure

fig, ax_l = plt.subplots(2,2)
plt.show()

# %%
x = np.arange(0, 10, 0.2) # what type is this?
print("Type of 'x': ", type(x))
y = np.sin(x) # what about this?
print("Type of 'y': ", type(y))
fig = plt.figure() # creates a new figure
ax = fig.add_subplot(111) #adds an AXES object?
print("Type of 'ax': ", type(ax))
ax.plot(x, y)
plt.show()
# Out:
# Type of 'x':  <class 'numpy.ndarray'>
# Type of 'y':  <class 'numpy.ndarray'>
# Type of 'ax':  <class 'matplotlib.axes._subplots.AxesSubplot'>
