# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
# %matplotlib inline

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.shape
# Out:
# (10886, 12)

# %%
train[0:600].plot(x="datetime", y="count")
