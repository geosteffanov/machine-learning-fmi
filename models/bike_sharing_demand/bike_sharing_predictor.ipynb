# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from datetime import datetime

# %%
# %matplotlib inline

# %%
def read_data(train_data_path, test_data_path):
    train = pd.read_csv(train_data_path)
    test = pd.read_csv(test_data_path)
    return train,test

# %%
def transform_data(data):
    data["casual"] = 0
    data["registered"] = 0
    
    parser = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S")
    
    dates = pd.DataFrame({"datetime" : parser(value) for value in data["datetime"]})
    dates["year"]= [date.year for date in dates[0]]
    dates["month"]= [date.month for date in dates[0]]
    dates["day"]= [date.day for date in dates[0]]
    dates = dates.drop("datetime", axis=1)
    data = data.drop(labels=["datetime", "casual", "registered"], axis=1)
    return pd.concat([data, dates], axis=1)

def splitXy(data, target):
    y = data[target]

# %%
train_transformed = transform_data(train)
test_transformed = transform_data(test)

# %%
X = train_transformed.drop("count", axis=1)
y = train_transformed["count"]

# data_to_encode = pd.concat([train_transformed["season"], test_transformed["season"]

from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoder.fit(all_data)

# X = encoder.transform(X)
# X_real = encoder.transform(test_transformed)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
X_test
# Out:
#        year  month  day  season  holiday  workingday  weather   temp   atemp  \
# 6495   2012      3    7       1        0           1        1  18.04  21.970
# 7050   2012      4   12       2        0           1        1  13.12  15.150
# 558    2011      2    6       1        0           0        1  12.30  14.395
# 5085   2011     12    5       4        0           1        2  18.86  22.725
# 3328   2011      8    8       3        0           1        1  33.62  37.120
# 1368   2011      4    2       2        0           0        1  13.12  15.150
# 3453   2011      8   13       3        0           0        2  27.88  31.820
# 1535   2011      4    9       2        0           0        2  15.58  19.695
# 449    2011      2    1       1        0           1        2   9.84  12.120
# 7626   2012      5   17       2        0           1        1  24.60  29.545
# 97     2011      1    5       1        0           1        1   8.20   9.850
# ...

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# -0.026932104391383715

# %%
test_transformed = transform_data(test)

# %%
clf.predict(X_real)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-2ba47c2766cd> in <module>()
# ----> 1 clf.predict(X_real)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
#     386         return X
#
# ...

# %%
dd

# %%
train_transformed
# Out:
#         atemp  casual  count  holiday  humidity  registered  season   temp  \
# 0      14.395     3.0   16.0      0.0      81.0        13.0     1.0   9.84
# 1      13.635     8.0   40.0      0.0      80.0        32.0     1.0   9.02
# 2      13.635     5.0   32.0      0.0      80.0        27.0     1.0   9.02
# 3      14.395     3.0   13.0      0.0      75.0        10.0     1.0   9.84
# 4      14.395     0.0    1.0      0.0      75.0         1.0     1.0   9.84
# 5      12.880     0.0    1.0      0.0      75.0         1.0     1.0   9.84
# 6      13.635     2.0    2.0      0.0      80.0         0.0     1.0   9.02
# 7      12.880     1.0    3.0      0.0      86.0         2.0     1.0   8.20
# 8      14.395     1.0    8.0      0.0      75.0         7.0     1.0   9.84
# 9      17.425     8.0   14.0      0.0      76.0         6.0     1.0  13.12
# 10     19.695    12.0   36.0      0.0      76.0        24.0     1.0  15.58
# ...
